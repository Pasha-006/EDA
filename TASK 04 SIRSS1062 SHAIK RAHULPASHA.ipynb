# %% [markdown]
# # Western U.S Cancer cases

# %%
import matplotlib as mpl
#importing matplotlib library
import matplotlib.pyplot as plt
import numpy as np
#importing numpy
import pandas as pd
#importing pandas
import seaborn as sns

# %%
# %matplotlib notebook

# %%
auto=pd.read_csv("C:/Users/shaik/OneDrive/Desktop/cancer.csv")
auto.head(10)
# Out:
#                   State  Total.Rate  Total.Number  Total.Population  \
# 0               Alabama       214.2       71529.0        33387205.0
# 1                Alaska       128.1        6361.0         4966180.0
# 2               Arizona       165.6       74286.0        44845598.0
# 3              Arkansas       223.9       45627.0        20382448.0
# 4            California       150.9      393980.0       261135696.0
# 5              Colorado       139.0       49035.0        35267734.0
# 6           Connecticut       190.5       47567.0        24975889.0
# 7              Delaware       210.2       13233.0         6295263.0
# 8  District of Columbia       182.1        7730.0         4245359.0
# 9               Florida       219.2      289905.0       132277071.0
#
#    Rates.Age.< 18  Rates.Age.18-45  Rates.Age.45-64  Rates.Age.> 64  \
# 0             2.0             18.5            244.7          1017.8
# 1             1.7             11.8            170.9           965.2
# ...

# %%
plt.figure(figsize=(6,6))
sns.lineplot(x = 'Total.Number', y = 'Total.Population', data = auto)
# Out:
# <img src="data:image/png;base64,..." width="600">
# <AxesSubplot:xlabel='Total.Number', ylabel='Total.Population'>

# %%
plt.figure(figsize=(6,6))
sns.lineplot(x = 'Rates.Age.> 64', y = 'Total.Population', data = auto)
# Out:
# <img src="data:image/png;base64,..." width="600">
# <AxesSubplot:xlabel='Rates.Age.> 64', ylabel='Total.Population'>

# %%
plt.figure(figsize=(6,6))
sns.lineplot(x = 'Rates.Age.45-64', y = 'Total.Population', data = auto)
# Out:
# <img src="data:image/png;base64,..." width="600">
# <AxesSubplot:xlabel='Rates.Age.45-64', ylabel='Total.Population'>

# %%
plt.figure(figsize=(6,6))
sns.lineplot(x = 'Rates.Age.18-45', y = 'Total.Population', data = auto)
# Out:
# <img src="data:image/png;base64,..." width="600">
# <AxesSubplot:xlabel='Rates.Age.18-45', ylabel='Total.Population'>

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x = 'Rates.Age.45-64', y = 'Total.Population', data = auto)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# <AxesSubplot:xlabel='Rates.Age.45-64', ylabel='Total.Population'>

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x = 'Rates.Age.< 18', y = 'Total.Population', data = auto)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# <AxesSubplot:xlabel='Rates.Age.< 18', ylabel='Total.Population'>

# %%
auto.max()
# Out:
# State                                     Wyoming
# Total.Rate                                  254.6
# Total.Number                               393980
# Total.Population                      2.61136e+08
# Rates.Age.< 18                                2.7
#                                          ...
# Types.Lung.Race.Black                        73.2
# Types.Lung.Race.Black non-Hispanic           73.6
# Types.Lung.Race.Asian                        33.9
# Types.Lung.Race.Indigenous                   87.5
# Types.Lung.Race.Hispanic                     35.2
# Length: 75, dtype: object

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x = 'Rates.Age and Sex.< 18.Male', y = 'Rates.Age and Sex.< 18.Female', data = auto)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# <AxesSubplot:xlabel='Rates.Age and Sex.< 18.Male', ylabel='Rates.Age and Sex.< 18.Female'>

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x = 'Rates.Age and Sex.< 18.Male', y = 'Rates.Age and Sex.< 18.Male', data = auto,linewidth=5)
plt.title('Female Vs Male')
# Out:
# <img src="data:image/png;base64,..." width="1200">
# Text(0.5, 1.0, 'Female Vs Male')

# %%
plt.figure(figsize=(10,7))
plt.style.use('seaborn-darkgrid')
sns.lineplot(data=auto['Rates.Age.< 18'],linewidth=1.5,label='age <18')
sns.lineplot(data=auto['Rates.Age.18-45'],linewidth=1.5,label='age in 18-45')
sns.lineplot(data=auto['Rates.Age.45-64'],linewidth=1.5,label='age 45-64')
sns.lineplot(data=auto['Rates.Age.> 64'],linewidth=1.5,label='age >64')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:ylabel='Rates.Age.< 18'>

# %%
plt.figure(figsize=(10,7))
plt.style.use('seaborn-darkgrid')
sns.lineplot(x='Rates.Age and Sex.< 18.Male',y='Rates.Age and Sex.< 18.Female',hue='Total.Rate',data=auto,style='Total.Rate',markers=True,linewidth=5)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='Rates.Age and Sex.< 18.Male', ylabel='Rates.Age and Sex.< 18.Female'>

# %%
plt.figure(figsize=(10,10))
sns.barplot(auto['Rates.Age and Sex.< 18.Male'],auto['Rates.Age and Sex.< 18.Female'])
# Out:
# <img src="data:image/png;base64,..." width="1000">
# C:\Users\shaik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rates.Age and Sex.< 18.Male', ylabel='Rates.Age and Sex.< 18.Female'>
